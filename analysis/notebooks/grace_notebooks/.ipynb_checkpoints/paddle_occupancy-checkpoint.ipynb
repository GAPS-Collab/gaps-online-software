# %%
import gaps_online as go
import gaps_online.db as db
import re
from glob import glob
import numpy as np
import math
from collections import defaultdict
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from pathlib import Path 
import os

# %%
#load calibrations
calib = go.tof.calibrations.load_calibrations(Path('/data1/nextcloud/cra_data/data/2023_nevis/tof/calibration/2024_03_12/'))

if len(calib.keys()) != 40: print('Oh no! Some calibrations are missing :(')
else: print('Yay! All calibration files were loaded :)')
# Out:
# Loading calibration files:  76%|███████████████████████████████████████████▊              | 31/41 [00:22<00:05,  1.77it/s]
# Failed to get RB ID from file /data1/nextcloud/cra_data/data/2023_nevis/tof/calibration/2024_03_12/Run125_1.2024_03_12-09_56_44.tof.gaps
# Loading calibration files: 100%|██████████████████████████████████████████████████████████| 41/41 [00:29<00:00,  1.39it/s]
# Yay! All calibration files were loaded :)

# %%
#get size of a file or set of files

def get_file_size_in_gb(file_path):
    size_in_bytes = os.path.getsize(file_path)
    size_in_gb = size_in_bytes / (1024**3)  # Convert bytes to gigabytes
    return size_in_gb

# %%
#load paths and populate empty data structures for later use

max_pulse_dict = defaultdict(list)
max_pulses = []

tof_events = []
fixed_path = "/data1/nextcloud/cra_data/data/2023_nevis/tof/142/Run142"


files = glob(f'{fixed_path}_*.tof.gaps')
#files = files [-5:]
print(len(files)) #checking to make sure files was populated
# Out:
# Variable size: 1.9073486328125e-05 GB
# 313

# %%
#basic method to acquire paddle id
paddle_ids = []
for fname in tqdm(files[-2:]):
    data = go.tof.get_tofpackets(fname, filter=go.cxx_api.PacketType.TofEvent)
    
    for ev in (go.cxx_api.TofEvent.from_tofpacket(k) for k in data):
        for rb in ev.get_rbids():
            rb_ev = ev.get_rbevent(rb)
            for h in rb_ev.hits:
                paddle_id = h.paddle_id
                paddle_ids.append(paddle_id)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def generate_paddle_ids(files):
    for fname in tqdm(files):
        data = go.tof.get_tofpackets(fname, filter=go.cxx_api.PacketType.TofEvent)
        for ev in (go.cxx_api.TofEvent.from_tofpacket(k) for k in data):
            for rb in ev.get_rbids():
                rb_ev = ev.get_rbevent(rb)
                for h in rb_ev.hits:
                    paddle_id = h.paddle_id
                    yield paddle_id

# %%
#not sorted by location
paddle_id_list = []

for paddle_id in generate_paddle_ids(files):
    paddle_id_list.append(paddle_id)

plt.hist(paddle_ids)
plt.title('Paddle Occupancy')
plt.xlabel('paddle_id')
plt.ylabel('count')
plt.show()
# Out:
#   0%|          | 0/313 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 3
#       1 paddle_id_list = []
# ----> 3 for paddle_id in generate_paddle_ids(files):
#       4     paddle_id_list.append(paddle_id)
#       6 plt.hist(paddle_ids)
#
# Cell In[34], line 3, in generate_paddle_ids(files)
#       1 def generate_paddle_ids(files):
#       2     for fname in tqdm(files):
# ----> 3         data = go.tof.get_tofpackets(fname, filter=go.cxx_api.PacketType.TofEvent)
#       4         for ev in (go.cxx_api.TofEvent.from_tofpacket(k) for k in data):
#       5             for rb in ev.get_rbids():
#
# KeyboardInterrupt:

# %%
cube_top = range(1, 13)
cube_bottom = range(13, 25)
cube_side = range(25, 57)
corner = range(57, 61)
cortina = range(109, 161)
umbrella = range(61, 109)

# cube_all = []
# cube_all.extend(cube_top)
# cube_all.extend(cube_bottom)
# cube_all.extend(corner)

# %%
cube_top_evts = []
cube_bottom_evts = []
cube_side_evts = []
corner_evts = []
cortina_evts = []
umbrella_evts = []

for paddle_id in generate_paddle_ids(files):
    if paddle_id in cube_top:
        cube_top_evts.append(paddle_id)
    elif paddle_id in cube_bottom:
        cube_bottom_evts.append(paddle_id)
    elif paddle_id in cube_side:
        cube_side_evts.append(paddle_id)
    elif paddle_id in corner:
        corner_evts.append(paddle_id)
    elif paddle_id in cortina:
        cortina_evts.append(paddle_id)
    elif paddle_id in umbrella:
        umbrella_evts.append(paddle_id)
# Out:
#   0%|          | 0/313 [00:00<?, ?it/s]

# %%
lists = [cube_top_evts, cube_bottom_evts, cube_side_evts, corner_evts, cortina_evts, umbrella_evts]
labels = ['Cube Top', 'Cube Bottom', 'Cube Side', 'Corner', 'Cortina', 'Umbrella']

# Create a figure with subplots
fig, axes = plt.subplots(nrows=len(lists), figsize=(8, 6))

# Plot histograms for each list
for ax, data, label in zip(axes, lists, labels):
    ax.hist(data)  # Adjust the number of bins as needed
    ax.set_title(label)
    ax.set_xlabel('paddle_id')
    ax.set_ylabel('count')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/gaps-online-u5ej2WuX-py3.10/lib/python3.10/site-packages/matplotlib/cbook.py:1404, in _reshape_2D(X, name)
#    1403 try:
# -> 1404     iter(xi)
#    1405 except TypeError:
#
# TypeError: 'int' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 9
#       7 # Plot histograms for each list
#       8 for ax, data, label in zip(axes, lists, labels):
# ----> 9     ax.hist(data)  # Adjust the number of bins as needed
#      10     ax.set_title(label)
#      11     ax.set_xlabel('paddle_id')
#
# File ~/.cache/pypoetry/virtualenvs/gaps-online-u5ej2WuX-py3.10/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/.cache/pypoetry/virtualenvs/gaps-online-u5ej2WuX-py3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py:6775, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6772     stacked = True
#    6774 # Massage 'x' for processing.
# -> 6775 x = cbook._reshape_2D(x, 'x')
#    6776 nx = len(x)  # number of datasets
#    6778 # Process unit information.  _process_unit_info sets the unit and
#    6779 # converts the first dataset; then we convert each following dataset
#    6780 # one at a time.
#
# File ~/.cache/pypoetry/virtualenvs/gaps-online-u5ej2WuX-py3.10/lib/python3.10/site-packages/matplotlib/cbook.py:1404, in _reshape_2D(X, name)
#    1402 if not isinstance(xi, str):
#    1403     try:
# -> 1404         iter(xi)
#    1405     except TypeError:
#    1406         pass
#
# KeyboardInterrupt:

# %%
panels = []

all_paddles = db.tof_paddle_manifest()

for paddle_id in generate_paddle_ids(files):
    panel = all_paddles[paddle_id]['panel'].panel_id
    panels.append(panel)
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[32], line 3
#       1 panels = []
# ----> 3 all_paddles = db.tof_paddle_manifest()
#       5 for paddle_id in generate_paddle_ids(files):
#       6     panel = all_paddles[paddle_id]['panel'].panel_id
#
# File /srv/apps/gaps-online-software/install-latest/python/gaps_online/db/manifest.py:43, in tof_paddle_manifest()
#      39 """
#      40 Get all TOF paddles
#      41 """
#      42 paddles = m.Paddle.objects.all()
# ---> 43 pids    = [(k.paddle_id, k) for k in paddles]
#      44 result  = dict()
#      45 for pid in pids:
#
# File ~/.cache/pypoetry/virtualenvs/gaps-online-u5ej2WuX-py3.10/lib/python3.10/site-packages/django/db/models/query.py:400, in QuerySet.__iter__(self)
#     385 def __iter__(self):
#     386     """
#     387     The queryset iterator protocol uses three nested iterators in the
#     388     default case:
#    (...)
#     398            - Responsible for turning the rows into model objects.
#     399     """
# --> 400     self._fetch_all()
#     401     return iter(self._result_cache)
#
# File ~/.cache/pypoetry/virtualenvs/gaps-online-u5ej2WuX-py3.10/lib/python3.10/site-packages/django/db/models/query.py:1928, in QuerySet._fetch_all(self)
#    1926 def _fetch_all(self):
#    1927     if self._result_cache is None:
# -> 1928         self._result_cache = list(self._iterable_class(self))
#    1929     if self._prefetch_related_lookups and not self._prefetch_done:
#    1930         self._prefetch_related_objects()
#
# File ~/.cache/pypoetry/virtualenvs/gaps-online-u5ej2WuX-py3.10/lib/python3.10/site-packages/django/db/models/query.py:91, in ModelIterable.__iter__(self)
#      88 compiler = queryset.query.get_compiler(using=db)
#      89 # Execute the query. This will also fill compiler.select, klass_info,
#      90 # and annotations.
# ---> 91 results = compiler.execute_sql(
#      92     chunked_fetch=self.chunked_fetch, chunk_size=self.chunk_size
#      93 )
#      94 select, klass_info, annotation_col_map = (
#      95     compiler.select,
#      96     compiler.klass_info,
#      97     compiler.annotation_col_map,
#      98 )
#      99 model_cls = klass_info["model"]
#
# File ~/.cache/pypoetry/virtualenvs/gaps-online-u5ej2WuX-py3.10/lib/python3.10/site-packages/django/db/models/sql/compiler.py:1560, in SQLCompiler.execute_sql(self, result_type, chunked_fetch, chunk_size)
#    1558     cursor = self.connection.chunked_cursor()
#    1559 else:
# -> 1560     cursor = self.connection.cursor()
#    1561 try:
#    1562     cursor.execute(sql, params)
#
# File ~/.cache/pypoetry/virtualenvs/gaps-online-u5ej2WuX-py3.10/lib/python3.10/site-packages/django/utils/asyncio.py:24, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      22 else:
#      23     if not os.environ.get("DJANGO_ALLOW_ASYNC_UNSAFE"):
# ---> 24         raise SynchronousOnlyOperation(message)
#      25 # Pass onward.
#      26 return func(*args, **kwargs)
#
# SynchronousOnlyOperation: You cannot call this from an async context - use a thread or sync_to_async.

# %%
plt.hist(cube_top_evts)
plt.title('Cube Top')
plt.xlabel('paddle_id')
plt.ylabel('count')
plt.show()

# %%
plt.hist(cube_side_evts)
plt.title('Cube Side')
plt.xlabel('paddle_id')
plt.ylabel('count')
plt.show()

# %%
plt.hist(cube_bottom_evts)
plt.title('Cube Bottom')
plt.xlabel('paddle_id')
plt.ylabel('count')
plt.show()

# %%
plt.hist(corner_evts)
plt.title('Corner')
plt.xlabel('paddle_id')
plt.ylabel('count')
plt.xticks(np.arange(57, 61, 1))
plt.show()

# %%
plt.hist(cortina_evts)
plt.title('Cortina')
plt.xlabel('paddle_id')
plt.ylabel('count')
plt.show()

# %%
plt.hist(umbrella_evts)
plt.title('Umbrella')
plt.xlabel('paddle_id')
plt.ylabel('count')
plt.show()
